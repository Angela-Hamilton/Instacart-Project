# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %%
# Path to Dataframe
path = r'C:\\Users\\maad0\\OneDrive\\CAREERFOUNDRY NOTES\\Python Fundamentals for Data Analyst\\08-2023 Instacart Basket Analysis'

# %%
# Import dataframe
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data','orders_products_merged.pkl'))

# %%
# Define a function
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'Highe-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product      21861997
# Low-range product      10126366
# Highe-range product      417678
# Name: price_range_loc, dtype: int64

# %%
# Using the max() function to check for the most expensive product
df_ords_prods_merged['prices'].max()
# Out:
# 99999.0

# %%
# Check for the busiest days of the week in ords_prods_merged dataframe
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204404
# 1    5660456
# 6    4496635
# 2    4213986
# 5    4205906
# 3    3840701
# 4    3783953
# Name: orders_day_of_week, dtype: int64

# %%
# Set Loop for orders_day_of_week
result = []
for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22417684
# Busiest day        6204404
# Least busy         3783953
# Name: busiest_day, dtype: int64

# %% [markdown]
# #### Question 2. Suppose your clients have changed their minds about the labels you created in your “busiest_day” column. Now, they want “Busiest day” to become “Busiest days” (plural). This label should correspond with the two busiest days of the week as opposed to the single busiest day. At the same time, they’d also like to know the two slowest days. Create a new column for this using a suitable method.

# %%
# Create new column for Busiest and Slowest Days
result_2 = []
for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_2.append("Busiest days")
  elif value == 3 or value == 4:
    result_2.append("Slowest days")
  else:
    result_2.append("Regularly busy days")

# %%
# Creating new column in ords_prods_merged dataframe
df_ords_prods_merged['busiest_days'] = result_2

# %%
# Check results
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy days    12916527
# Busiest days           11864860
# Slowest days            7624654
# Name: busiest_days, dtype: int64

# %% [markdown]
# ### Question 3. Check the values of this new column for accuracy. Note any observations in markdown format.

# %%
# Check for the busiest days of the week in ords_prods_merged dataframe
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204404
# 1    5660456
# 6    4496635
# 2    4213986
# 5    4205906
# 3    3840701
# 4    3783953
# Name: orders_day_of_week, dtype: int64

# %%
# Define function
def add_num(x,y):
    sum = x+y
    return sum

# %%
# Run Function for Busiest Days 0= Saturday; 1 = Sunday
add_num (6204404,5660456)
# Out:
# 11864860

# %%
# Run Function for Slowest Days 3= Tuesday; 4 = Wednesday
add_num (3840701,3783953)
# Out:
# 7624654

# %% [markdown]
# ### In checking the value of the new column the value count matches the value count of the orders_day_of_week my df_ords_prods_merged dataframe.

# %% [markdown]
# ### Question 4. When too many users make Instacart orders at the same time, the app freezes. The senior technical officer at Instacart wants you to identify the busiest hours of the day. Rather than by hour, they want periods of time labeled “Most orders,” “Average orders,” and “Fewest orders.” Create a new column containing these labels called “busiest_period_of_day.

# %%
# Identify busiest hour of the day
df_ords_prods_merged['orders_time_of_day'].value_counts()
# Out:
# 10    2761862
# 11    2736242
# 14    2689251
# 15    2662246
# 13    2661057
# 12    2618613
# 16    2535313
# 9     2454273
# 17    2087721
# 8     1718182
# 18    1636566
# 19    1258352
# 20     976182
# 7      891082
# 21     795658
# 22     634247
# 23     402335
# 6      290500
# 0      218786
# 1      115706
# 5       87964
# 2       69377
# 4       53245
# 3       51281
# Name: orders_time_of_day, dtype: int64

# %% [markdown]
# #### We can divide the number of hours in a day by 3 (number of labels to find the busiest periods of the day).  In doing so, we find the following:
#     ##### Most Orders are from 9am- 4pm.
#     ##### Fewest Orders are from 11 pm , and also from 12am - 6am.
#     ##### Average Orders are from 7am - 8am and also from 5pm -10pm.

# %%
# Set Loop for orders_time_of_day
time_of_day = []
for value in df_ords_prods_merged["orders_time_of_day"]:
  if value in [9,10,11,12,13,14,15,16]:
    time_of_day.append("Most Orders")
  elif value in [23,6,0,1,5,2,4,3]:
    time_of_day.append("Fewest Orders")
  else:
    time_of_day.append("Average Orders")

# %%
# Create new column as busiest_period_of_day
df_ords_prods_merged['busiest_period_of_day'] = time_of_day

# %%
# Checking results for new labels
time_of_day
# Out:
# ['Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
# ...

# %% [markdown]
# ### Question 5. Print the frequency for this new column.

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts()
# Out:
# Most Orders       21118857
# Average Orders     9997990
# Fewest Orders      1289194
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ### Question 7. Export your dataframe as a pickle file.

# %%
# Exporting updated dataframe
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_v4.pkl'))
